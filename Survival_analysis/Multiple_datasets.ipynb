# %%
#!pip install ISLP
# !pip uninstall numpy
# !pip install --no-cache-dir numpy

# %%
from matplotlib.pyplot import subplots
import numpy as np
import pandas as pd
from ISLP.models import ModelSpec as MS
from ISLP import load_data

# %%
# New imports
from lifelines import (KaplanMeierFitter, CoxP
